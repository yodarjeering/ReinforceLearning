# %% [markdown]
# # Import library

# %%
import numpy as np
import math
import glob
import matplotlib.pyplot as plt
from enum import Enum
import pandas as pd
import time
from collections import defaultdict

# %% [markdown]
# # State class

# %%
class State():
    
    
    def __init__(self, price_pct):
        # price_pct : 株価の変化率, アナログ
        self.price_pct = price_pct

# %% [markdown]
# # Action class

# %%
class Action(Enum):
    STAY = 0 #買わない
    BUY = 1   #買う

# %% [markdown]
# # Environment class

# %%
class Environment():
    
    
    def __init__(self, price_chart, pct_chart, n_divide, time=0):
        self.price_chart = price_chart
        self.pct_chart = pct_chart
        self.n_divide = n_divide
        self.time = time
        self.start = time
        
    def reset(self):
        self.time = self.start
        return self.state(self.pct_chart['close'].iloc[self.time])
            
    
    def actions(self):
        return [Action.STAY, Action.BUY]
    
    
    def state(self, price_pct):#アナログ変化率をインデックス化
        list_ = sorted(self.pct_chart['close'].tolist())
        sride = len(list_)//self.n_divide
        
        
        for i in range(self.n_divide):
            if list_[i*sride] <= price_pct < list_[(i+1)*sride]:
                return i
        return i+1

            
    
    def reward_func(self):
        if self.time+1>=len(self.price_chart):
            return 0, True
        else:
            return self.price_chart['close'].iloc[self.time+1]-self.price_chart['open'].iloc[self.time+1], False
    
    
    def step(self, action):
        done=False
        
        
        if self.time+1>=len(self.pct_chart):
            return None, 0, True
        
        
        price_pct = self.pct_chart['close'].iloc[self.time+1]
        next_state = self.state(price_pct)
        self.time += 1
        
        
        if action==Action.STAY:#STAY
            reward=0
        else:
            reward, done =self.reward_func()
            
            
        return next_state, reward, done

# %% [markdown]
# # QLAgent class

# %%
class QLAgent():
    
    
    def __init__(self, epsilon):
        self.epsilon = epsilon
        self.Q = {}
        
        
    def policy(self, s, actions):
        if np.random.random() < self.epsilon:
            return np.random.randint(len(actions))
        else:
            if s in self.Q and sum(self.Q[s])!=0:
                return np.argmax(self.Q[s])
            else:
                return np.random.randint(len(actions))

# %% [markdown]
# # MonteCarlo Agent class

# %%
class MonteCarloAgent(QLAgent):
    
    
    def __init__(self, episode_count=100, epsilon=0.1):
        super().__init__(epsilon)
        self.episode_count = episode_count
        
        
    def learn(self, env,  gamma=0.9):
        actions = env.actions()
        self.Q = defaultdict(lambda: [0] * len(actions))
        N = defaultdict(lambda: [0] * len(actions))
        reward_episode = []
        
        
        for e in range(self.episode_count):
            s = env.reset()
            done = False
            experience = []
            reward_log = []
#             print("-----------------------")
#             print("episode :",e)
           
            while not done:
                a = self.policy(s, actions)
                action = actions[a]
                n_state, reward, done = env.step(action)
                experience.append({"state":s,"action":a,"reward":reward})
                s = n_state
                reward_log.append(reward)
              
            
            reward_episode.append(sum(reward_log))
#             print("Total rewards in 1 episode :",reward_episode[-1])
            for i, x in enumerate(experience):
                s, a = x["state"], x["action"]
                
                
                G, t = 0, 0
                for j in range(i, len(experience)):
                    G += math.pow(gamma, t)*experience[j]["reward"]
                    t+=1
                    
                    
                N[s][a] += 1
                alpha = 1 / N[s][a]
                self.Q[s][a] += alpha * (G - self.Q[s][a])
        print("reward graph")  
        plt.plot(reward_episode)
        plt.show()
        
        
                
    def reward_mean(self, reward_log):
        reward_log = np.array(reward_log)
        return np.mean(reward_log)
    
    
    def estimate(self, env):
        actions = env.actions()
        reward_episode = []
        done = False
        s = env.reset()
        profit = 0
        
        
        while not done:
            a = self.policy(s, actions)
            action = actions[a]
            n_state, reward, done = env.step(action)
            s = n_state
            profit += reward
            reward_episode.append(profit)
            
            
        print("reward graph")  
        print("Total reward :",reward_episode[-1])
        plt.plot(reward_episode)
        plt.show()

# %% [markdown]
# # Temporal Difference Agent class

# %%
class TemporalDifferenceAgent(QLAgent):
    
    
    def __init__(self, episode_count=100, epsilon=0.1):
        super().__init__(epsilon)
        self.episode_count = episode_count
        
        
    def learn(self, env, learning_rate=0.1, gamma=0.9):
        actions = env.actions()
        self.Q = defaultdict(lambda: [0] * len(actions))
        reward_episode = []
        
        
        for e in range(self.episode_count):
            s = env.reset()
            done = False
            experience = []
            reward_log = []
#             print("-----------------------")
#             print("episode :",e)
           
            
            while not done:
                a = self.policy(s, actions)
                action = actions[a]
                n_state, reward, done = env.step(action)

                
                gain = reward + gamma*max(self.Q[n_state]) 
                estimated = self.Q[s][a]
                self.Q[s][a] += learning_rate * (gain - estimated)
                s = n_state
                reward_log.append(reward)
                    
            
            reward_episode.append(sum(reward_log))
#             print("Total rewards in 1 episode :",reward_episode[-1])

        
        print("reward graph")  
        plt.plot(reward_episode)
        plt.show()
        
        
                
    def reward_mean(self, reward_log):
        reward_log = np.array(reward_log)
        return np.mean(reward_log)
    
    
    def estimate(self, env):
        actions = env.actions()
        reward_episode = []
        profit = 0
        done = False
        s = env.reset()

        
        
        while not done:
            a = self.policy(s, actions)
            action = actions[a]
            n_state, reward, done = env.step(action)
            s = n_state
            profit += reward
            reward_episode.append(profit)
            
            
        print("reward graph")  
        print("Total reward :",reward_episode[-1])
        
        plt.plot(reward_episode)
        plt.show()

# %% [markdown]
# # load df

# %%
def load_df(path_):

    
    FILE = glob.glob(path_)
    df = pd.read_csv(FILE[0])
    df = df.rename(columns={df.columns[0]:'nan',df.columns[1]:'nan',df.columns[2]:'nan',\
                                df.columns[3]:'day',df.columns[4]:'nan',df.columns[5]:'open',\
                                df.columns[6]:'high',df.columns[7]:'low',df.columns[8]:'close',\
                                   df.columns[9]:'nan',})

    df = df.drop('nan',axis=1)
    df = df.drop(df.index[0])
    df['day'] = pd.to_datetime(df['day'],format='%Y/%m/%d')
    df.set_index('day',inplace=True)
    
    
    return df.astype(float)

# %% [markdown]
# # train func

# %%
path_ = '/Users/rince/Desktop/StockPriceData/Stock_index/NFNK225_10years.csv'
price_chart = load_df(path_)
pct_chart = price_chart.pct_change()

# %%
pct_chart = pct_chart.iloc[-250:]
price_chart = price_chart.iloc[-250:]

# %%
# def train():
# #     agent = TemporalDifferenceAgent(epsilon=0.1)
for e in [50,100]:
    print("e ",e)
#     agent = MonteCarloAgent(episode_count=e,epsilon=0.1)
    agent = TemporalDifferenceAgent(episode_count=e,epsilon=0.1)a
    test_rate = 0.9
    length = len(price_chart)
    test_rate *= length
    test_rate = int(test_rate)

    env_train = Environment(price_chart.iloc[1:test_rate], pct_chart.iloc[1:test_rate], n_divide=99)
    agent.learn(env_train)


    env_test = Environment(price_chart.iloc[test_rate:], pct_chart.iloc[test_rate:], n_divide=99)
    agent.estimate(env_test)
    print("===============================")
#     print(agent.Q)

# %%
start_time = time.time()
train()
print("calc time :",time.time()-start_time)
# Out:
# -----------------------
# episode : 0
# Total rewards in 1 episode : 170.0
# -----------------------
# episode : 1
# Total rewards in 1 episode : 12540.0
# -----------------------
# episode : 2
# Total rewards in 1 episode : 13200.0
# -----------------------
# episode : 3
# Total rewards in 1 episode : 12990.0
# -----------------------
# episode : 4
# Total rewards in 1 episode : 14390.0
# -----------------------
# episode : 5
# Total rewards in 1 episode : 15660.0
# -----------------------
# episode : 6
# Total rewards in 1 episode : 14450.0
# -----------------------
# episode : 7
# Total rewards in 1 episode : 18110.0
# -----------------------
# episode : 8
# Total rewards in 1 episode : 15630.0
# -----------------------
# episode : 9
# Total rewards in 1 episode : 15650.0
# -----------------------
# episode : 10
# Total rewards in 1 episode : 15260.0
# -----------------------
# episode : 11
# Total rewards in 1 episode : 14450.0
# -----------------------
# episode : 12
# Total rewards in 1 episode : 14570.0
# -----------------------
# episode : 13
# Total rewards in 1 episode : 11850.0
# -----------------------
# episode : 14
# Total rewards in 1 episode : 18040.0
# -----------------------
# episode : 15
# Total rewards in 1 episode : 14510.0
# -----------------------
# episode : 16
# Total rewards in 1 episode : 19340.0
# -----------------------
# episode : 17
# Total rewards in 1 episode : 15000.0
# -----------------------
# episode : 18
# Total rewards in 1 episode : 16790.0
# -----------------------
# episode : 19
# Total rewards in 1 episode : 16980.0
# -----------------------
# episode : 20
# Total rewards in 1 episode : 19620.0
# -----------------------
# episode : 21
# Total rewards in 1 episode : 16580.0
# -----------------------
# episode : 22
# Total rewards in 1 episode : 16640.0
# -----------------------
# episode : 23
# Total rewards in 1 episode : 17840.0
# -----------------------
# episode : 24
# Total rewards in 1 episode : 16110.0
# -----------------------
# episode : 25
# Total rewards in 1 episode : 14230.0
# -----------------------
# episode : 26
# Total rewards in 1 episode : 17830.0
# -----------------------
# episode : 27
# Total rewards in 1 episode : 18040.0
# -----------------------
# episode : 28
# Total rewards in 1 episode : 17120.0
# -----------------------
# episode : 29
# Total rewards in 1 episode : 15600.0
# -----------------------
# episode : 30
# Total rewards in 1 episode : 17680.0
# -----------------------
# episode : 31
# Total rewards in 1 episode : 17290.0
# -----------------------
# episode : 32
# Total rewards in 1 episode : 19240.0
# -----------------------
# episode : 33
# Total rewards in 1 episode : 13830.0
# -----------------------
# episode : 34
# Total rewards in 1 episode : 15830.0
# -----------------------
# episode : 35
# Total rewards in 1 episode : 18230.0
# -----------------------
# episode : 36
# Total rewards in 1 episode : 17990.0
# -----------------------
# episode : 37
# Total rewards in 1 episode : 18280.0
# -----------------------
# episode : 38
# Total rewards in 1 episode : 18180.0
# -----------------------
# episode : 39
# Total rewards in 1 episode : 18590.0
# -----------------------
# episode : 40
# Total rewards in 1 episode : 18990.0
# -----------------------
# episode : 41
# Total rewards in 1 episode : 16440.0
# -----------------------
# episode : 42
# Total rewards in 1 episode : 19680.0
# -----------------------
# episode : 43
# Total rewards in 1 episode : 16240.0
# -----------------------
# episode : 44
# Total rewards in 1 episode : 17530.0
# -----------------------
# episode : 45
# Total rewards in 1 episode : 16200.0
# -----------------------
# episode : 46
# Total rewards in 1 episode : 20970.0
# -----------------------
# episode : 47
# Total rewards in 1 episode : 20600.0
# -----------------------
# episode : 48
# Total rewards in 1 episode : 17000.0
# -----------------------
# episode : 49
# Total rewards in 1 episode : 18550.0
# -----------------------
# episode : 50
# Total rewards in 1 episode : 20270.0
# -----------------------
# episode : 51
# Total rewards in 1 episode : 21610.0
# -----------------------
# episode : 52
# Total rewards in 1 episode : 18540.0
# -----------------------
# episode : 53
# Total rewards in 1 episode : 14580.0
# -----------------------
# episode : 54
# Total rewards in 1 episode : 21690.0
# -----------------------
# episode : 55
# Total rewards in 1 episode : 19840.0
# -----------------------
# episode : 56
# Total rewards in 1 episode : 19000.0
# -----------------------
# episode : 57
# Total rewards in 1 episode : 19100.0
# -----------------------
# episode : 58
# Total rewards in 1 episode : 21060.0
# -----------------------
# episode : 59
# Total rewards in 1 episode : 19470.0
# -----------------------
# episode : 60
# Total rewards in 1 episode : 19850.0
# -----------------------
# episode : 61
# Total rewards in 1 episode : 18300.0
# -----------------------
# episode : 62
# Total rewards in 1 episode : 20670.0
# -----------------------
# episode : 63
# Total rewards in 1 episode : 19190.0
# -----------------------
# episode : 64
# Total rewards in 1 episode : 21360.0
# -----------------------
# episode : 65
# Total rewards in 1 episode : 18840.0
# -----------------------
# episode : 66
# Total rewards in 1 episode : 20430.0
# -----------------------
# episode : 67
# Total rewards in 1 episode : 19390.0
# -----------------------
# episode : 68
# Total rewards in 1 episode : 17990.0
# -----------------------
# episode : 69
# Total rewards in 1 episode : 20150.0
# -----------------------
# episode : 70
# Total rewards in 1 episode : 21510.0
# -----------------------
# episode : 71
# Total rewards in 1 episode : 22900.0
# -----------------------
# episode : 72
# Total rewards in 1 episode : 20960.0
# -----------------------
# episode : 73
# Total rewards in 1 episode : 19980.0
# -----------------------
# episode : 74
# Total rewards in 1 episode : 19590.0
# -----------------------
# episode : 75
# Total rewards in 1 episode : 21640.0
# -----------------------
# episode : 76
# Total rewards in 1 episode : 24160.0
# -----------------------
# episode : 77
# Total rewards in 1 episode : 20970.0
# -----------------------
# episode : 78
# Total rewards in 1 episode : 24690.0
# -----------------------
# episode : 79
# Total rewards in 1 episode : 19880.0
# -----------------------
# episode : 80
# Total rewards in 1 episode : 20850.0
# -----------------------
# episode : 81
# Total rewards in 1 episode : 20080.0
# -----------------------
# episode : 82
# Total rewards in 1 episode : 22510.0
# -----------------------
# episode : 83
# Total rewards in 1 episode : 20900.0
# -----------------------
# episode : 84
# Total rewards in 1 episode : 20310.0
# -----------------------
# episode : 85
# Total rewards in 1 episode : 21660.0
# -----------------------
# episode : 86
# Total rewards in 1 episode : 22490.0
# -----------------------
# episode : 87
# Total rewards in 1 episode : 23430.0
# -----------------------
# episode : 88
# Total rewards in 1 episode : 22060.0
# -----------------------
# episode : 89
# Total rewards in 1 episode : 22870.0
# -----------------------
# episode : 90
# Total rewards in 1 episode : 21320.0
# -----------------------
# episode : 91
# Total rewards in 1 episode : 22880.0
# -----------------------
# episode : 92
# Total rewards in 1 episode : 21640.0
# -----------------------
# episode : 93
# Total rewards in 1 episode : 21630.0
# -----------------------
# episode : 94
# Total rewards in 1 episode : 22800.0
# -----------------------
# episode : 95
# Total rewards in 1 episode : 22040.0
# -----------------------
# episode : 96
# Total rewards in 1 episode : 21390.0
# -----------------------
# episode : 97
# Total rewards in 1 episode : 24420.0
# -----------------------
# episode : 98
# Total rewards in 1 episode : 22170.0
# -----------------------
# episode : 99
# Total rewards in 1 episode : 21460.0
# reward graph
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-15-c4cedca534e2> in <module>
#       1 start_time = time.time()
# ----> 2 train()
#       3 print("calc time :",time.time()-start_time)
#
# <ipython-input-14-8cd84cde876a> in train()
#      12
#      13     env_test = Environment(price_chart.iloc[test_rate:], pct_chart.iloc[test_rate:], n_divide=99)
# ---> 14     agent.estimate(env_test)
#      15
#      16 #     print(agent.Q)
#
# <ipython-input-9-a29723f1f8b3> in estimate(self, env)
#      64
#      65         while not done:
# ---> 66             a = self.policy(s, actions)
#      67             action = actions[a]
#      68             n_state, reward, done = env.step(action)
#
# UnboundLocalError: local variable 's' referenced before assignment

# %%
pct_chart
# Out:
#                 open      high       low     close
# day
# 2020-06-01  0.005732  0.009632  0.008857  0.007912
# 2020-06-02  0.011399  0.010841  0.010097  0.013956
# 2020-06-03  0.026441  0.018447  0.015645  0.015054
# 2020-06-04  0.006757  0.005476  0.001712  0.000000
# 2020-06-05 -0.012164 -0.003770  0.002563  0.007203
# ...              ...       ...       ...       ...
# 2021-06-01  0.000000 -0.001653 -0.006361 -0.001336
# 2021-06-02 -0.010299 -0.003311 -0.001685  0.004681
# 2021-06-03  0.006714  0.004983  0.010462  0.004992
# 2021-06-04  0.000000 -0.004959 -0.003006 -0.004967
# 2021-06-07  0.010337  0.008306  0.006700  0.000000
#
# [250 rows x 4 columns]
